# %% [markdown]
# <a href="https://colab.research.google.com/github/NeoByteVoyager/DeepLearning/blob/main/Notes/CNN/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 一.Image in computer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 二.Why not fully connected network?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The parameters is so many,it is **difficult to train** and increase the risk of **overfitting**

# %% [markdown]
# ## Three observations

# %% [markdown]
# ### Observation 1

# %% [markdown]
# Human identify one photo by some pattern in it.
# Computer does not have to see the whole image, it only need to focus on some patterns

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Simplification 1

# %% [markdown]
# **set receptive field to find some pattern:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **typical setting:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **kernel:** include all channels
# - **kernel size:** 3x3

# %% [markdown]
# ## Observation 2

# %% [markdown]
# The same pattern appears in **different regions**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Simplification 2

# %% [markdown]
# Each rectptive field has **a set of neurons** with **the same set of parameters**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Simplification 1&2 (Convolution Layer)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Observation 3

# %% [markdown]
# **subsample** the photo will not change the object.

# %% [markdown]
# ## Simplication 3

# %% [markdown]
# **pooling** - get the max (or mean ) from a field:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Convolution and Pooling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## The whole CNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)
