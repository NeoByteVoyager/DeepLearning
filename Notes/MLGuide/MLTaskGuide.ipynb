# %% [markdown]
# <a href="https://colab.research.google.com/github/NeoByteVoyager/DeepLearning/blob/main/Notes/MLGuide/MLTaskGuide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # General Guide

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Loss on training data is large

# %% [markdown]
# ## 1.Model Bias

# %% [markdown]
# - The model is too simple
# - **Solution:** redesign your model to make it more flexible (eg:increase in_features,use DL…… )
#
# > No needle in a haystack

# %% [markdown]
# ## 2. Optimization

# %% [markdown]
# - find the local mini,but does not find the global min
# - **Solution:**
#   - start from shallower networks,which are easier to optimize
#   - If deeper networks does not obtain smaller loss on **training data** $→$ optimization issue
#
# > needle is in a haystack,but can not find it

# %% [markdown]
# ## 3.Model Bias vs Optimization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Model is larger,but loss is higher(On the training data) $→$ **Optimization is worse**

# %% [markdown]
# ## eg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. n-16-1 AdamW
# 2. n-16-8-1 AdamW
# 3. n-16-1 SGD
# 4. n-16-8-1 SGD

# %% [markdown]
# - **1 vs 4:** 4's model is more complex,but loss is lager $→$ 4'optimizer is worse
# - **1 vs 2 && 3 vs 4:** more complex model's loss is smaller $→$ 16-1 is simple

# %% [markdown]
# # Loss on training data is small

# %% [markdown]
# ## Loss on testing data is large

# %% [markdown]
# ### Overfitting

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **model is so worse** that become if_else on training data
# - **model is so large** that it is **very flexible**

# %% [markdown]
# **Solution:**
#   - More training data
#   - Data augmentation
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
#   - constained model
#     - Less parameters,sharing parameters
#     - Less features(useful,strong relative)
#     - Early stopping
#     - Dropout
#     - Regularization
