# %% [markdown]
# <a href="https://colab.research.google.com/github/NeoByteVoyager/DeepLearning/blob/main/Notes/Transformer/Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Target

# %% [markdown]
# **seq 2 seq**.The output length is **determined by model**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Encoder

# %% [markdown]
# ## Framework

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Simplification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Original paper

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Decoder

# %% [markdown]
# ## Framework

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Each time Decoder's input is **the last output** and Encoder's output
# - Each output is **generated one by one**
# - The output **ends with the word "end"**
# > This is called **auto regressive**

# %% [markdown]
# ## Mask Self-attention

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## AT vs NAT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **NAT decoder:**
#   -  Another predictor for **output length**
#   -  Output a very long sequence, and **ignore tokens after END**
#
# **Advantages:**
#   - **parallel**
#   - **controllable** output length
#
# > It performs **worse than AT**

# %% [markdown]
# # Encoder to Decoder

# %% [markdown]
# ## Cross Attention

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Decoder generate **query vector** by **masked self-attention**
# 2. Encoder's output generate vector $k,v$
# 3. Calculate $K^T Q$

# %% [markdown]
# # Train

# %% [markdown]
# ## Framework

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - According to the labels, machine **minimizes cross entopy**
# - Decoder's input is **ground truth** (not it's last output)
