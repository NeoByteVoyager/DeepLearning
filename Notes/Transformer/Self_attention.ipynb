# %% [markdown]
# <a href="https://colab.research.google.com/github/NeoByteVoyager/DeepLearning/blob/main/Notes/Transformer/Self_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Input

# %% [markdown]
# Input is **a set of vectors**,such as **words**,**voice**

# %% [markdown]
# ## Output

# %% [markdown]
# - **Each vector** has a label

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **The whole sequence** has a label

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **Model decides** the number of label itself

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # The framework of Self Attention

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Self Attention Module

# %% [markdown]
# ## Calculate process

# %% [markdown]
# 1. Find the **relevant vectors** in a sequence

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Calculate relevant

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - More detailed

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - The relevant to **itself** and activation function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. **Extract information** based on **attention score**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Matrix view

# %% [markdown]
# - Get **Q,K,V**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - $K^TQ$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - $V A '$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Summary

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Multi-head self-attention

# %% [markdown]
# **Different types of relevance**

# %% [markdown]
# - $q^i、k^i、v^i$ transform to two vectors,and calculate **separately**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
