# %% [markdown]
# <a href="https://colab.research.google.com/github/NeoByteVoyager/DeepLearning/blob/main/Notes/AutoEncoder/AutoEncoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic idea of auto-encoder

# %% [markdown]
# - **Encoder:** Dimension reduction
# - **Decoder:** Feature restoration

# %% [markdown]
# ## Auto-encoder

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## De-noising Auto-encoder

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Feature disentangle

# %% [markdown]
# ## Definition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Every dimension **learn different features**

# %% [markdown]
# ## Application

# %% [markdown]
# ### Voice conversion

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Discrete latent representation

# %% [markdown]
# ## Definition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## VQVAE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **Codebook:** A set of discrete vectors
#
# Select discrete vector by computing similarity of the encoder output and codebook vectors

# %% [markdown]
# ## Text as representation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Encoder ouput is a set of tokens(summary), but need a discriminator to update generator to make it like human

# %% [markdown]
# # More application

# %% [markdown]
# ## Generator

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Decoder can be a generator, input a seq of vectors and output an image

# %% [markdown]
# ## Compression

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Anomaly detection

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **One class** classification problem: **there are many samples of one class, but has little other class samples(can not train a classificer)**
