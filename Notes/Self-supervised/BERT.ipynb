# %% [markdown]
# <a href="https://colab.research.google.com/github/NeoByteVoyager/DeepLearning/blob/main/Notes/Self-supervised/BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Self-supervised Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Masking Input

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. masking some tokens
# 2. masked sequence as input, output **a distribution, vs one-hot**

# %% [markdown]
# # Framework

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. **pre-train** the BERT model which can **only fill the blank**
# 2. **fine-tune** the model to make it can **do other tasks**

# %% [markdown]
# # How to use BERT

# %% [markdown]
# ## Case1: Classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **model:** pre-trained BERT and a linear network

# %% [markdown]
# ## Case2:Sequence to sequence

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 进行词性标注

# %% [markdown]
# ## Case3:Two sequences to a class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Case4:QA(Answer is in the document)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Two vectors should be **random initialized**
# - One vector is the start vector, the other is the end vector
