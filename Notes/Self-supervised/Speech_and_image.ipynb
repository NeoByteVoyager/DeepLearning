# %% [markdown]
# <a href="https://colab.research.google.com/github/NeoByteVoyager/DeepLearning/blob/main/Notes/Self-supervised/Speech_and_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Generative approaches

# %% [markdown]
# ## Speech

# %% [markdown]
# ### BERT Masking

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Masking some tokens and reconstruct the vectors(like text BERT)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Voice signal is the similar to the neighbor signal → masking continuous signals
# 2. Masking specific dimensions → learn more about speaker information

# %% [markdown]
# ### GPT Predict future

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Predict the next is so easy, so we usually predict **the third**(or further)

# %% [markdown]
# ## Image

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - This prove GPT and BERT(transformer) can learn about image

# %% [markdown]
# Speech and image contain many detailis that are **difficult to generate**

# %% [markdown]
# # 2.Predict approaches

# %% [markdown]
# ## Speech

# %% [markdown]
# ### 1.Context prediction

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Learn by **predict the distance between two short audio segments**

# %% [markdown]
# ### 2.Predict simplified objects

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Transform the audio signal to **"token"**, and use language model to do the work

# %% [markdown]
# ## Image

# %% [markdown]
# ### 1. Predict rotation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Leaning representation by making machine predict rotation
# - learning rotation → must learn some feature

# %% [markdown]
# ### 2.Context prediction

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Learn feature representation by **learning the position relation of the patches of the photo**

# %% [markdown]
# # 3.Contrastive learning

# %% [markdown]
# ## Image

# %% [markdown]
# ### 1. SimCLR

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create positive pairs by **data augmentation**, and learn to make the pairs as close as possible

# %% [markdown]
# ## Speech

# %% [markdown]
# ### 1.SimCLR

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.Wav2vec

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tokenizer + BERT**
# - Discrete is not good enough, so hidden and output are vectors
# - Output tansform to token

# %% [markdown]
# Selecting negative examples is **not easy**

# %% [markdown]
# # 4.Bootstrap

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5.Simply extra regularization

# %% [markdown]
# ## Variance-Invariance-Covariance

# %% [markdown]
# ![image.png](data:image/png;base64,...)
